# %% [markdown]
#  Week 3: Predictive Modeling (Churn Prediction)

# %%
import pandas as pd

df = pd.read_csv("cleaned_hotel_bookings.csv")

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[['lead_time', 'average_daily_rate', 'total_guests', 'total_nights']]
y = df['cancellation_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Model (Logistic Regression)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Accuracy

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.6613198900091659

# %% [markdown]
# Precision & Recall

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.87      0.77      8292
#          1.0       0.57      0.30      0.39      4800
#
#     accuracy                           0.66     13092
#    macro avg       0.63      0.59      0.58     13092
# weighted avg       0.64      0.66      0.63     13092

# %% [markdown]
# ROC-AUC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

y_prob = model.predict_proba(X_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label="AUC = %0.2f" % roc_auc)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC-AUC Curve")
plt.legend()
plt.show()
